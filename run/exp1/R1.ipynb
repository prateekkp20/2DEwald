# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('R1.csv')
df.head(10)
# Out:
#       File    Reciprocal      Time  Reciprocal(Integral)    Time.1     error  \
# 0  POSCAR1   8537.094042  0.028297           8537.094162  0.015957  0.000120
# 1      NaN   8537.094042  0.026983           8537.094162  0.031734  0.000120
# 2      NaN   8537.094042  0.027537           8537.094162  0.025677  0.000120
# 3      NaN   8537.094042  0.027071           8537.094162  0.019327  0.000120
# 4      NaN   8537.094042  0.026930           8537.094162  0.015986  0.000120
# 5  POSCAR2  24942.128517  0.107501          24942.127900  0.038925  0.000617
# 6      NaN  24942.128517  0.114208          24942.127900  0.036369  0.000617
# 7      NaN  24942.128517  0.102817          24942.127900  0.037551  0.000617
# 8      NaN  24942.128517  0.102462          24942.127900  0.037144  0.000617
# 9      NaN  24942.128517  0.102811          24942.127900  0.037086  0.000617
#
#    %Reduction in Time(For Integral)  Reciprocal(3DFFT)    Time.2     error.1  \
# 0                         43.610722        8092.516214  0.030596  444.577828
# 1                         17.605923        8092.516214  0.032530  444.577828
# 2                          6.755965        8092.516214  0.033419  444.577828
# 3                         28.607048        8092.516214  0.032516  444.577828
# 4                         40.639287        8092.516214  0.033704  444.577828
# 5                         63.791295       24342.852468  0.038851  599.276049
# 6                         68.155339       24342.852468  0.039398  599.276049
# 7                         63.478161       24342.852468  0.038172  599.276049
# 8                         63.748248       24342.852468  0.038998  599.276049
# 9                         63.928262       24342.852468  0.039257  599.276049
#
#           Real    Time.3         Total
# 0  1371.795958  0.000097   1785.528204
# 1  1371.795958  0.000094   1785.528204
# 2  1371.795958  0.000095   1785.528204
# 3  1371.795958  0.000095   1785.528204
# 4  1371.795958  0.000096   1785.528204
# 5  4533.967868  0.000359  13229.372792
# 6  4533.967868  0.000345  13229.372792
# 7  4533.967868  0.000361  13229.372792
# 8  4533.967868  0.000355  13229.372792
# 9  4533.967868  0.000363  13229.372792

# %%
new_df = df.drop(columns=['File'],inplace=False)
df['Reciprocal'].mean()
new_df.head(10)
# Out:
#      Reciprocal      Time  Reciprocal(Integral)    Time.1     error  \
# 0   8537.094042  0.028297           8537.094162  0.015957  0.000120
# 1   8537.094042  0.026983           8537.094162  0.031734  0.000120
# 2   8537.094042  0.027537           8537.094162  0.025677  0.000120
# 3   8537.094042  0.027071           8537.094162  0.019327  0.000120
# 4   8537.094042  0.026930           8537.094162  0.015986  0.000120
# 5  24942.128517  0.107501          24942.127900  0.038925  0.000617
# 6  24942.128517  0.114208          24942.127900  0.036369  0.000617
# 7  24942.128517  0.102817          24942.127900  0.037551  0.000617
# 8  24942.128517  0.102462          24942.127900  0.037144  0.000617
# 9  24942.128517  0.102811          24942.127900  0.037086  0.000617
#
#    %Reduction in Time(For Integral)  Reciprocal(3DFFT)    Time.2     error.1  \
# 0                         43.610722        8092.516214  0.030596  444.577828
# 1                         17.605923        8092.516214  0.032530  444.577828
# 2                          6.755965        8092.516214  0.033419  444.577828
# 3                         28.607048        8092.516214  0.032516  444.577828
# 4                         40.639287        8092.516214  0.033704  444.577828
# 5                         63.791295       24342.852468  0.038851  599.276049
# 6                         68.155339       24342.852468  0.039398  599.276049
# 7                         63.478161       24342.852468  0.038172  599.276049
# 8                         63.748248       24342.852468  0.038998  599.276049
# 9                         63.928262       24342.852468  0.039257  599.276049
#
#           Real    Time.3         Total
# 0  1371.795958  0.000097   1785.528204
# 1  1371.795958  0.000094   1785.528204
# 2  1371.795958  0.000095   1785.528204
# 3  1371.795958  0.000095   1785.528204
# 4  1371.795958  0.000096   1785.528204
# 5  4533.967868  0.000359  13229.372792
# 6  4533.967868  0.000345  13229.372792
# 7  4533.967868  0.000361  13229.372792
# 8  4533.967868  0.000355  13229.372792
# 9  4533.967868  0.000363  13229.372792

# %%
step = 5
out = new_df.groupby(new_df.index//step).mean()
out.head(5)
# Out:
#      Reciprocal      Time  Reciprocal(Integral)    Time.1     error  \
# 0   8537.094042  0.027364           8537.094162  0.021736  0.000120
# 1  24942.128517  0.105960          24942.127900  0.037415  0.000617
# 2  16858.918725  0.245686          16858.918249  0.053703  0.000476
# 3  23377.601612  0.433610          23377.601975  0.078916  0.000363
# 4  13144.864811  0.694923          13144.863664  0.116320  0.001147
#
#    %Reduction in Time(For Integral)  Reciprocal(3DFFT)    Time.2      error.1  \
# 0                         27.443789        8092.516214  0.032553   444.577828
# 1                         64.620261       24342.852468  0.038935   599.276049
# 2                         78.022540       16202.399652  0.046981   656.519073
# 3                         81.766023       22280.717817  0.055953  1096.883795
# 4                         83.566743       12029.786981  0.065746  1115.077830
#
#           Real    Time.3         Total
# 0  1371.795958  0.000095   1785.528204
# 1  4533.967868  0.000357  13229.372792
# 2  1559.565723  0.000759  -5951.600942
# 3 -3801.490674  0.001514 -12917.336248
# 4 -2199.667595  0.002216 -29671.611766

# %%
out.insert(0, "Number of Atoms", [200,400,600,800,1000,1500,3000,6000,12000,24000,30000,48000], True)
out.insert(11,"Real(lammps)", [1371.7613,4533.7298,1559.9991,-3801.5667,-2199.8632,-364.06602,-2184.4484,-142202.86,144314.75,0,30000,48000], True) #could only calculate the real values in lammps upto 12k atoms
out.insert(13,"Total(lammps)", [ 1785.4417 , 13229.106 , -5951.2131 , -12917.467 , -29671.886 , -32179.811 , -44110.817 , -302903.8 , -22842.976 ,0,0,0 ], True) 
out.insert(15,"Elong(lammps)", [  413.68036 , 8695.3767 , -7511.2122 , -9115.9007 , -27472.023 , -31815.745 , -41926.368 , -160700.93 , -167157.72 ,0,0,0], True) 
out.to_csv('MEAN.csv')
out.head(9)
# Out:
#    Number of Atoms     Reciprocal       Time  Reciprocal(Integral)    Time.1  \
# 0              200    8537.094042   0.027364           8537.094162  0.021736
# 1              400   24942.128517   0.105960          24942.127900  0.037415
# 2              600   16858.918725   0.245686          16858.918249  0.053703
# 3              800   23377.601612   0.433610          23377.601975  0.078916
# 4             1000   13144.864811   0.694923          13144.863664  0.116320
# 5             1500   29109.561771   1.440890          29109.561266  0.158411
# 6             3000   79924.175395   5.682702          79924.176525  0.413471
# 7             6000   83000.135244  24.679696          83000.140357  1.124138
# 8            12000  320244.399131  98.694301         320244.395329  3.716041
#
#       error  %Reduction in Time(For Integral)  Reciprocal(3DFFT)    Time.2  \
# 0  0.000120                         27.443789        8092.516214  0.032553
# 1  0.000617                         64.620261       24342.852468  0.038935
# 2  0.000476                         78.022540       16202.399652  0.046981
# 3  0.000363                         81.766023       22280.717817  0.055953
# 4  0.001147                         83.566743       12029.786981  0.065746
# 5  0.000505                         89.005375       26745.785429  0.093653
# 6  0.001130                         92.722498       78133.806719  0.229586
# 7  0.005113                         95.444812       79491.657690  0.722114
# 8  0.003802                         96.234902      308453.903196  2.589197
#
#         error.1           Real  Real(lammps)    Time.3  Total(lammps)  \
# 0    444.577828    1371.795958    1371.76130  0.000095      1785.4417
# 1    599.276049    4533.967868    4533.72980  0.000357     13229.1060
# 2    656.519073    1559.565723    1559.99910  0.000759     -5951.2131
# 3   1096.883795   -3801.490674   -3801.56670  0.001514    -12917.4670
# 4   1115.077830   -2199.667595   -2199.86320  0.002216    -29671.8860
# 5   2363.776342    -363.458262    -364.06602  0.004867    -32179.8110
# 6   1790.368676   -2185.942427   -2184.44840  0.018262    -44110.8170
# 7   3508.477554 -142208.507357 -142202.86000  0.072447   -302903.8000
# 8  11790.495935  144319.373172  144314.75000  0.289074    -22842.9760
#
#            Total  Elong(lammps)
# 0    1785.528204      413.68036
# 1   13229.372792     8695.37670
# 2   -5951.600942    -7511.21220
# 3  -12917.336248    -9115.90070
# 4  -29671.611766   -27472.02300
# 5  -32179.109964   -31815.74500
# 6  -44112.193977   -41926.36800
# 7 -302909.226003  -160700.93000
# 8  -22837.935477  -167157.72000

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,6))
fig.suptitle("PHL 2D Ewald")
ax[0].plot('Number of Atoms','Time', data=out[out['Number of Atoms'] < 1001], marker='*', alpha=0.4)
ax[0].set_xlabel("Number of Atoms")
ax[0].set_ylabel("Time (sec)")
ax[0].grid()
 
# And now add something in the second part:
# ax[1].plot(  'Number of Atoms','Time', data=out[out['Number of Atoms'] > 1001], marker='*', alpha=0.3)
ax[1].plot(  'Number of Atoms','Time', data = out[(out['Number of Atoms'] < 12001) & (out['Number of Atoms'] > 1001)]
, marker='*', alpha=0.3)
ax[1].set_xlabel("Number of Atoms")
ax[1].set_ylabel("Time (sec)")
ax[1].grid()
# Show the graph
plt.show()

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,6))
fig.suptitle("Integral 2D Ewald")
ax[0].plot('Number of Atoms','Time.1', data=out[out['Number of Atoms'] < 1001], marker='*', alpha=0.4)
ax[0].set_xlabel("Number of Atoms")
ax[0].set_ylabel("Time (sec)")
ax[0].grid()
 
# And now add something in the second part:
ax[1].plot(  'Number of Atoms','Time.1', data=out[(out['Number of Atoms'] < 12001) & (out['Number of Atoms'] > 1001)], marker='*', alpha=0.3)
ax[1].set_xlabel("Number of Atoms")
ax[1].set_ylabel("Time (sec)")
ax[1].grid()
# Show the graph
plt.show()

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,6))
fig.suptitle("Error b/w Integral and PHL 2D Ewald (kcal/mol)")
ax[0].plot('Number of Atoms','error', data=out[out['Number of Atoms'] < 1001], marker='*', alpha=0.4)
ax[0].set_xlabel("Number of Atoms")
ax[0].set_ylabel("Error")
ax[0].grid()
 
# And now add something in the second part:
ax[1].plot(  'Number of Atoms','error', data=out[(out['Number of Atoms'] < 12001) & (out['Number of Atoms'] > 1001)], marker='*', alpha=0.3)
ax[1].set_xlabel("Number of Atoms")
ax[1].set_ylabel("Error")
ax[1].grid()
# Show the graph
plt.show()

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,6))
fig.suptitle("% Reduction in Time")
ax[0].plot('Number of Atoms','%Reduction in Time(For Integral)', data=out[out['Number of Atoms'] < 1001], marker='*', alpha=0.4)
ax[0].set_xlabel("Number of Atoms")
ax[0].grid()
 
# And now add something in the second part:
ax[1].plot(  'Number of Atoms','%Reduction in Time(For Integral)', data=out[out['Number of Atoms'] > 1001], marker='*', alpha=0.3)
ax[1].set_xlabel("Number of Atoms")
ax[1].grid()
# Show the graph
plt.show()

# %%
fft = out[['Number of Atoms','Reciprocal(3DFFT)','Time.2','error.1']].copy()
fft['error.1']*=4.184
fft.head(9)
# Out:
#    Number of Atoms  Reciprocal(3DFFT)    Time.2       error.1
# 0              200        8092.516214  0.032553   1860.113631
# 1              400       24342.852468  0.038935   2507.370989
# 2              600       16202.399652  0.046981   2746.875799
# 3              800       22280.717817  0.055953   4589.361799
# 4             1000       12029.786981  0.065746   4665.485641
# 5             1500       26745.785429  0.093653   9890.040216
# 6             3000       78133.806719  0.229586   7490.902540
# 7             6000       79491.657690  0.722114  14679.470085
# 8            12000      308453.903196  2.589197  49331.434990

# %%
integral = out[['Number of Atoms','Reciprocal(Integral)','Time.1','error']].copy()
integral['error']*=4.184
integral.head(9)
# Out:
#    Number of Atoms  Reciprocal(Integral)    Time.1     error
# 0              200           8537.094162  0.021736  0.000500
# 1              400          24942.127900  0.037415  0.002581
# 2              600          16858.918249  0.053703  0.001990
# 3              800          23377.601975  0.078916  0.001518
# 4             1000          13144.863664  0.116320  0.004799
# 5             1500          29109.561266  0.158411  0.002111
# 6             3000          79924.176525  0.413471  0.004728
# 7             6000          83000.140357  1.124138  0.021394
# 8            12000         320244.395329  3.716041  0.015908

# %%
real = out[['Number of Atoms','Real','Time.3','Real(lammps)']].copy()
real['Error'] = abs(real['Real']- real['Real(lammps)'])*4.184
real.head(9)
# Out:
#    Number of Atoms           Real    Time.3  Real(lammps)      Error
# 0              200    1371.795958  0.000095    1371.76130   0.145009
# 1              400    4533.967868  0.000357    4533.72980   0.996077
# 2              600    1559.565723  0.000759    1559.99910   1.813251
# 3              800   -3801.490674  0.001514   -3801.56670   0.318091
# 4             1000   -2199.667595  0.002216   -2199.86320   0.818410
# 5             1500    -363.458262  0.004867    -364.06602   2.542859
# 6             3000   -2185.942427  0.018262   -2184.44840   6.251008
# 7             6000 -142208.507357  0.072447 -142202.86000  23.628541
# 8            12000  144319.373172  0.289074  144314.75000  19.343353

# %%
total = out[['Number of Atoms','Total','Total(lammps)']].copy()
total['Error'] = abs(total['Total']- total['Total(lammps)'])*4.184
total.head(9)
# Out:
#    Number of Atoms          Total  Total(lammps)      Error
# 0              200    1785.528204      1785.4417   0.361932
# 1              400   13229.372792     13229.1060   1.116259
# 2              600   -5951.600942     -5951.2131   1.622731
# 3              800  -12917.336248    -12917.4670   0.547068
# 4             1000  -29671.611766    -29671.8860   1.147397
# 5             1500  -32179.109964    -32179.8110   2.933136
# 6             3000  -44112.193977    -44110.8170   5.761272
# 7             6000 -302909.226003   -302903.8000  22.702397
# 8            12000  -22837.935477    -22842.9760  21.089549
