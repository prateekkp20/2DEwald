# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('R1.csv')
df.head(10)
# Out:
#       File   Reciprocal      Time  Reciprocal(Integral)    Time.1  \
# 0  POSCAR1  6556.119277  0.030970           6556.119274  0.017531
# 1      NaN  6556.119277  0.029917           6556.119274  0.033466
# 2      NaN  6556.119277  0.041768           6556.119274  0.028531
# 3      NaN  6556.119277  0.038724           6556.119274  0.057485
# 4      NaN  6556.119277  0.031596           6556.119274  0.019323
# 5  POSCAR2  4740.055374  0.118573           4740.055373  0.038899
# 6      NaN  4740.055374  0.105864           4740.055373  0.046053
# 7      NaN  4740.055374  0.116805           4740.055373  0.050624
# 8      NaN  4740.055374  0.118476           4740.055373  0.057653
# 9      NaN  4740.055374  0.124098           4740.055373  0.061982
#
#           error  %Reduction in Time(For Integral)  Reciprocal(3DFFT)  \
# 0  2.536937e-06                         43.392231        6376.705200
# 1  2.536945e-06                         11.864519        6376.705200
# 2  2.536946e-06                         31.692763        6376.705200
# 3  2.536952e-06                         48.449251        6376.705200
# 4  2.536957e-06                         38.841708        6376.705200
# 5  7.138506e-07                         67.193669        4754.234677
# 6  7.138742e-07                         56.497472        4754.234677
# 7  7.138815e-07                         56.659677        4754.234677
# 8  7.138487e-07                         51.338426        4754.234677
# 9  7.138506e-07                         50.053837        4754.234677
#
#      Time.2     error.1        Real    Time.3        Total
# 0  0.033723  179.414077 -869.296373  0.000096  -115.578300
# 1  0.035046  179.414077 -869.296373  0.000098  -115.578300
# 2  0.033538  179.414077 -869.296373  0.000091  -115.578300
# 3  0.034535  179.414077 -869.296373  0.000092  -115.578300
# 4  0.032753  179.414077 -869.296373  0.000098  -115.578300
# 5  0.039433   14.179304 -631.608644  0.000346 -7496.355677
# 6  0.038347   14.179304 -631.608644  0.000350 -7496.355677
# 7  0.039848   14.179304 -631.608644  0.000346 -7496.355677
# 8  0.040113   14.179304 -631.608644  0.000353 -7496.355677
# 9  0.041123   14.179304 -631.608644  0.000358 -7496.355677

# %%
new_df = df.drop(columns=['File'],inplace=False)
df['Reciprocal'].mean()
new_df.head(10)
# Out:
#     Reciprocal      Time  Reciprocal(Integral)    Time.1         error  \
# 0  6556.119277  0.030970           6556.119274  0.017531  2.536937e-06
# 1  6556.119277  0.029917           6556.119274  0.033466  2.536945e-06
# 2  6556.119277  0.041768           6556.119274  0.028531  2.536946e-06
# 3  6556.119277  0.038724           6556.119274  0.057485  2.536952e-06
# 4  6556.119277  0.031596           6556.119274  0.019323  2.536957e-06
# 5  4740.055374  0.118573           4740.055373  0.038899  7.138506e-07
# 6  4740.055374  0.105864           4740.055373  0.046053  7.138742e-07
# 7  4740.055374  0.116805           4740.055373  0.050624  7.138815e-07
# 8  4740.055374  0.118476           4740.055373  0.057653  7.138487e-07
# 9  4740.055374  0.124098           4740.055373  0.061982  7.138506e-07
#
#    %Reduction in Time(For Integral)  Reciprocal(3DFFT)    Time.2     error.1  \
# 0                         43.392231        6376.705200  0.033723  179.414077
# 1                         11.864519        6376.705200  0.035046  179.414077
# 2                         31.692763        6376.705200  0.033538  179.414077
# 3                         48.449251        6376.705200  0.034535  179.414077
# 4                         38.841708        6376.705200  0.032753  179.414077
# 5                         67.193669        4754.234677  0.039433   14.179304
# 6                         56.497472        4754.234677  0.038347   14.179304
# 7                         56.659677        4754.234677  0.039848   14.179304
# 8                         51.338426        4754.234677  0.040113   14.179304
# 9                         50.053837        4754.234677  0.041123   14.179304
#
#          Real    Time.3        Total
# 0 -869.296373  0.000096  -115.578300
# 1 -869.296373  0.000098  -115.578300
# 2 -869.296373  0.000091  -115.578300
# 3 -869.296373  0.000092  -115.578300
# 4 -869.296373  0.000098  -115.578300
# 5 -631.608644  0.000346 -7496.355677
# 6 -631.608644  0.000350 -7496.355677
# 7 -631.608644  0.000346 -7496.355677
# 8 -631.608644  0.000353 -7496.355677
# 9 -631.608644  0.000358 -7496.355677

# %%
step = 5
out = new_df.groupby(new_df.index//step).mean()
out.head(5)
# Out:
#      Reciprocal      Time  Reciprocal(Integral)    Time.1         error  \
# 0   6556.119277  0.034595           6556.119274  0.031267  2.536948e-06
# 1   4740.055374  0.116763           4740.055373  0.051042  7.138611e-07
# 2  17554.467789  0.261021          17554.467787  0.058549  1.667503e-06
# 3  21385.450364  0.442061          21385.450357  0.115772  7.461403e-06
# 4  14825.543250  0.636638          14825.543257  0.096083  6.679845e-06
#
#    %Reduction in Time(For Integral)  Reciprocal(3DFFT)    Time.2     error.1  \
# 0                         34.848094        6376.705200  0.033919  179.414077
# 1                         56.348616        4754.234677  0.039773   14.179304
# 2                         77.561498       17459.600164  0.047965   94.867625
# 3                         74.537415       21396.803032  0.061095   11.352668
# 4                         84.904719       14052.735361  0.066476  772.807889
#
#           Real    Time.3         Total
# 0  -869.296373  0.000095   -115.578300
# 1  -631.608644  0.000351  -7496.355677
# 2 -2158.700618  0.000759  -2011.436439
# 3  2254.799800  0.001393    430.645351
# 4  2227.585257  0.002141 -11958.877510

# %%
out.insert(0, "Number of Atoms", [200,400,600,800,1000,1500,3000,6000,12000], True)
out.insert(11,"Real(lammps)", [-869.25803,-632.46612,-2158.8831,2254.9336,2227.4784,10437.245 , -4683.6405 ,32582.576,-160807.4], True) 
out.insert(13,"Total(lammps)", [-115.88,-7497.0279,-2011.784,430.43245,-11959.159,3387.7696 ,3163.28 ,97797.503,-298186.69], True) 
out.insert(15,"Elong(lammps)", [753.37803,-6864.5618,147.09907,-1824.5012,-14186.638, -7049.4754, 7846.9205,65214.927,-137379.29], True) 
out.to_csv('MEAN.csv')
out.head(9)
# Out:
#    Number of Atoms     Reciprocal       Time  Reciprocal(Integral)    Time.1  \
# 0              200    6556.119277   0.034595           6556.119274  0.031267
# 1              400    4740.055374   0.116763           4740.055373  0.051042
# 2              600   17554.467789   0.261021          17554.467787  0.058549
# 3              800   21385.450364   0.442061          21385.450357  0.115772
# 4             1000   14825.543250   0.636638          14825.543257  0.096083
# 5             1500   36470.774633   1.547165          36470.774623  0.206609
# 6             3000   94882.195850   5.737037          94882.195831  0.413318
# 7             6000  239304.219884  24.611831         239304.219947  1.218338
# 8            12000  210733.205114  98.683222         210733.205227  3.795006
#
#           error  %Reduction in Time(For Integral)  Reciprocal(3DFFT)  \
# 0  2.536948e-06                         34.848094        6376.705200
# 1  7.138611e-07                         56.348616        4754.234677
# 2  1.667503e-06                         77.561498       17459.600164
# 3  7.461403e-06                         74.537415       21396.803032
# 4  6.679845e-06                         84.904719       14052.735361
# 5  1.025514e-05                         86.550703       35006.520613
# 6  1.955655e-05                         92.780297       93614.797279
# 7  6.274501e-05                         95.047241      234650.894729
# 8  1.122817e-04                         96.154429      204441.914826
#
#      Time.2      error.1           Real  Real(lammps)    Time.3  \
# 0  0.033919   179.414077    -869.296373    -869.25803  0.000095
# 1  0.039773    14.179304    -631.608644    -632.46612  0.000351
# 2  0.047965    94.867625   -2158.700618   -2158.88310  0.000759
# 3  0.061095    11.352668    2254.799800    2254.93360  0.001393
# 4  0.066476   772.807889    2227.585257    2227.47840  0.002141
# 5  0.095571  1464.254020   10434.640721   10437.24500  0.004766
# 6  0.232387  1267.398571   -4684.736466   -4683.64050  0.018479
# 7  0.739469  4653.325155   32564.646044   32582.57600  0.072477
# 8  2.624217  6291.290288 -160774.652206 -160807.40000  0.290054
#
#    Total(lammps)          Total  Elong(lammps)
# 0     -115.88000    -115.578300      753.37803
# 1    -7497.02790   -7496.355677    -6864.56180
# 2    -2011.78400   -2011.436439      147.09907
# 3      430.43245     430.645351    -1824.50120
# 4   -11959.15900  -11958.877510   -14186.63800
# 5     3387.76960    3387.406328    -7049.47540
# 6     3163.28000    3161.441335     7846.92050
# 7    97797.50300   97796.829828    65214.92700
# 8  -298186.69000 -298185.519291  -137379.29000

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,6))
fig.suptitle("PHL 2D Ewald")
ax[0].plot('Number of Atoms','Time', data=out[out['Number of Atoms'] < 3001], marker='*', alpha=0.4)
ax[0].set_xlabel("Number of Atoms")
ax[0].set_ylabel("Time (sec)")
ax[0].grid()
 
# And now add something in the second part:
ax[1].plot(  'Number of Atoms','Time', data=out[out['Number of Atoms'] > 3001], marker='*', alpha=0.3)
ax[1].set_xlabel("Number of Atoms")
ax[1].set_ylabel("Time (sec)")
ax[1].grid()
# Show the graph
plt.show()

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,6))
fig.suptitle("Integral 2D Ewald")
ax[0].plot('Number of Atoms','Time.1', data=out[out['Number of Atoms'] < 3001], marker='*', alpha=0.4)
ax[0].set_xlabel("Number of Atoms")
ax[0].set_ylabel("Time (sec)")
ax[0].grid()
 
# And now add something in the second part:
ax[1].plot(  'Number of Atoms','Time.1', data=out[out['Number of Atoms'] > 3001], marker='*', alpha=0.3)
ax[1].set_xlabel("Number of Atoms")
ax[1].set_ylabel("Time (sec)")
ax[1].grid()
# Show the graph
plt.show()

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,6))
fig.suptitle("Error b/w Integral and PHL 2D Ewald (kcal/mol)")
ax[0].plot('Number of Atoms','error', data=out[out['Number of Atoms'] < 3001], marker='*', alpha=0.4)
ax[0].set_xlabel("Number of Atoms")
ax[0].set_ylabel("Error")
ax[0].grid()
 
# And now add something in the second part:
ax[1].plot(  'Number of Atoms','error', data=out[out['Number of Atoms'] > 3001], marker='*', alpha=0.3)
ax[1].set_xlabel("Number of Atoms")
ax[1].set_ylabel("Error")
ax[1].grid()
# Show the graph
plt.show()

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,6))
fig.suptitle("% Reduction in Time")
ax[0].plot('Number of Atoms','%Reduction in Time(For Integral)', data=out[out['Number of Atoms'] < 3001], marker='*', alpha=0.4)
ax[0].set_xlabel("Number of Atoms")
ax[0].grid()
 
# And now add something in the second part:
ax[1].plot(  'Number of Atoms','%Reduction in Time(For Integral)', data=out[out['Number of Atoms'] > 3001], marker='*', alpha=0.3)
ax[1].set_xlabel("Number of Atoms")
ax[1].grid()
# Show the graph
plt.show()

# %%
fft = out[['Number of Atoms','Reciprocal(3DFFT)','Time.2','error.1']].copy()
fft['error.1']*=4.184
fft.head(9)
# Out:
#    Number of Atoms  Reciprocal(3DFFT)    Time.2       error.1
# 0              200        6376.705200  0.033919    750.668497
# 1              400        4754.234677  0.039773     59.326207
# 2              600       17459.600164  0.047965    396.926144
# 3              800       21396.803032  0.061095     47.499563
# 4             1000       14052.735361  0.066476   3233.428207
# 5             1500       35006.520613  0.095571   6126.438818
# 6             3000       93614.797279  0.232387   5302.795623
# 7             6000      234650.894729  0.739469  19469.512450
# 8            12000      204441.914826  2.624217  26322.758565

# %%
integral = out[['Number of Atoms','Reciprocal(Integral)','Time.1','error']].copy()
integral['error']*=4.184
integral.head(9)
# Out:
#    Number of Atoms  Reciprocal(Integral)    Time.1     error
# 0              200           6556.119274  0.031267  0.000011
# 1              400           4740.055373  0.051042  0.000003
# 2              600          17554.467787  0.058549  0.000007
# 3              800          21385.450357  0.115772  0.000031
# 4             1000          14825.543257  0.096083  0.000028
# 5             1500          36470.774623  0.206609  0.000043
# 6             3000          94882.195831  0.413318  0.000082
# 7             6000         239304.219947  1.218338  0.000263
# 8            12000         210733.205227  3.795006  0.000470

# %%
real = out[['Number of Atoms','Real','Time.3','Real(lammps)']].copy()
real['Error'] = abs(real['Real']- real['Real(lammps)'])*4.184
real.head(9)
# Out:
#    Number of Atoms           Real    Time.3  Real(lammps)       Error
# 0              200    -869.296373  0.000095    -869.25803    0.160427
# 1              400    -631.608644  0.000351    -632.46612    3.587678
# 2              600   -2158.700618  0.000759   -2158.88310    0.763506
# 3              800    2254.799800  0.001393    2254.93360    0.559821
# 4             1000    2227.585257  0.002141    2227.47840    0.447089
# 5             1500   10434.640721  0.004766   10437.24500   10.896305
# 6             3000   -4684.736466  0.018479   -4683.64050    4.585520
# 7             6000   32564.646044  0.072477   32582.57600   75.018937
# 8            12000 -160774.652206  0.290054 -160807.40000  137.016772

# %%
total = out[['Number of Atoms','Total','Total(lammps)']].copy()
total['Error'] = abs(total['Total']- total['Total(lammps)'])*4.184
total.head(9)
# Out:
#    Number of Atoms          Total  Total(lammps)     Error
# 0              200    -115.578300     -115.88000  1.262314
# 1              400   -7496.355677    -7497.02790  2.812579
# 2              600   -2011.436439    -2011.78400  1.454196
# 3              800     430.645351      430.43245  0.890776
# 4             1000  -11958.877510   -11959.15900  1.177756
# 5             1500    3387.406328     3387.76960  1.519928
# 6             3000    3161.441335     3163.28000  7.692975
# 7             6000   97796.829828    97797.50300  2.816552
# 8            12000 -298185.519291  -298186.69000  4.898246
